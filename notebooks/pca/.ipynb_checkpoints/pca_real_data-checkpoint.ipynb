# %%
import pickle
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
num_components = 50
normalize = True

# %%
with open('/home/aleks/hackatum/flavorscape/data/recipes_10k.pkl', 'rb') as file:
    data_pd = pickle.load(file)

min_entries_attribute = 5
min_entries_recipe = 10
    
data_pd = (data_pd.reset_index()
                  .drop_duplicates(subset='index', keep='last')
                  .set_index('index').sort_index())

# %%
alias_ingredient_classes = {
    'beef': [],
    'chicken': [],
    'turkey': [],
    'pork': [],
    'fish': ['salmon', 'tuna'],
    'egg': [],
    'dairy-product': ['milk', 'cheese', 'yoghurt'],
    'bread': [],
    'tortilla': [],
    'pasta': [],
    'rice': [],
    'root-veg': ['potato', 'carrot'],
    'broccoli': ['broccoli', 'cauliflower'],
    'seed': [],
    'legume': ['bean', 'pea'],
    'mushroom': [],
    'nuts': [],
    'cereal': [],
}

filter_suffices = ['mix', 'concentrate', 'glace', 'soup', 'sauce']
filter_prefixes = ['c-', 't-']

for key, value in alias_ingredient_classes.items():
    value.append(key)
    classes = [col for col in data_pd.columns if not [s for s in filter_suffices if col.endswith(s)] 
               and not [s for s in filter_prefixes if col.startswith(s)]
               and [v for v in value if v in col]]
    alias_ingredient_classes[key] = classes

# %%
alias_pd = pd.DataFrame(index=data_pd.index)

for key, cols in alias_ingredient_classes.items():
    alias_pd.insert(len(alias_pd.columns), key, data_pd[cols].any(axis=1).astype('int'))

# %%
data_pd = pd.concat([alias_pd, data_pd], axis=1)

data_pd = data_pd.drop(data_pd.columns[data_pd.sum(axis=0)<2*min_entries_attribute], axis=1)
data_pd = data_pd.drop(data_pd.index[data_pd.sum(axis=1)<min_entries_recipe], axis=0)
data_pd = data_pd.drop(data_pd.columns[data_pd.sum(axis=0)<min_entries_attribute], axis=1)
print(data_pd.shape)

columns = data_pd.columns
columns_tag = [c for c in columns if c.startswith('t-')]
columns_cuisine = [c for c in columns if c.startswith('c-')]
columns_ingredient_classes = [c for c in columns if c in alias_ingredient_classes.keys()]
columns_ingredients = [c for c in columns if c not in columns_tag + columns_cuisine + columns_ingredient_classes]
columns_tag_important = [
    't-spicy',
    't-protein-smart',
    't-calorie-smart',
    't-veggie',
    't-easy',
    't-vegan',
    't-plant-based']

multiplier_ingredient_classes = 20
multiplier_tag_important = 20
# Out:
# (2947, 412)

# %%
data_mean = data_pd.mean(axis=0)
data_std = data_pd.std(axis=0)

if normalize:
    data_pd_norm = (data_pd - data_mean) / data_std
else:
    data_pd_norm = data_pd - data_mean

# %%
data_pd_norm[columns_tag_important] *= multiplier_tag_important
data_pd_norm[columns_ingredient_classes] *= multiplier_ingredient_classes

# %%
data_np = data_pd.to_numpy()
data_np.shape
# Out:
# (2947, 412)

# %%
occurence = data_pd.sum(axis=0).sort_values(ascending=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(occurence)
# Out:
# salt                                                2880
# pepper                                              2830
# dairy-product                                       2335
# butter-milk                                         1630
# olive-oil                                           1458
# cooking-oil                                         1376
# c-american                                          1360
# root-veg                                            1057
# sour-cream                                           996
# garlic                                               922
# scallions                                            832
# chicken                                              794
# sugar                                                758
# legume                                               736
# lemon                                                721
# rice                                                 664
# ...

# %%
pca = PCA(n_components=num_components)
dim_reduced_data = pca.fit_transform(data_np)

# %%
highlight = 'beef'

highlight_idx = data_pd.columns.get_loc(highlight)

for i in range(0, min(num_components, 20), 2):
    plt.figure()
    plt.scatter(dim_reduced_data[:,i], dim_reduced_data[:,i+1], c=data_np[:,highlight_idx])

# %%
num_recipes = 20
recipe = 'One-Pot Turkey, Cauliflower & Bean Soup'
print(recipe)

idx = data_pd.index.get_loc(recipe)

diff = (dim_reduced_data - dim_reduced_data[idx])
dist = np.sqrt(np.sum(diff*diff, axis=1))
sorted_idx = dist.argsort()

print(f'\nTop {num_recipes} similar:')
for i in sorted_idx[:num_recipes]:
    print(f'{round(dist[i],2)}: {data_pd.index[i]}')
    
print(f'\nTop {num_recipes} dissimilar:')
for i in sorted_idx[-num_recipes:]:
    print(f'{round(dist[i],2)}: {data_pd.index[i]}')
# Out:
# One-Pot Turkey, Cauliflower & Bean Soup
#
# Top 20 similar:
# 0.0: One-Pot Turkey, Cauliflower & Bean Soup
# 0.93: One-Pot Turkey Cauliflower & Bean Soup
# 1.09: One-Pot Vegan Cauliflower & Bean Soup
# 2.07: One-Pot Mexicali Turkey & Bean Soup
# 2.08: One-Pot Beef, Cauliflower & Bean Soup
# 2.28: Vegan Tex-Mex Black Bean & Pepper Wrap
# 2.44: One-Pot Beef & Black Bean Soup
# 2.66: One-Pan Pineapple Salsa Turkey Tacos
# 2.74: Vegan Tex-Mex Black Bean & Pepper Wraps
# 2.8: One-Pot Black Bean & Pepper Soup
# 2.89: One-Pot Mexicali Black Bean Soup
# 2.94: One-Pan Cheesy Turkey & Black Bean Tacos
# 2.95: One-Pan Turkey & Pineapple Tacos
# 2.95: One-Pot Cowboy Turkey & Bean Chili
# 2.98: Salsa Verde Turkey Enchiladas
# 3.02: Turkey, Sweet Potato & Bean Tostadas
# 3.1: Smashed Black Bean & Turkey Tostadas
# 3.11: One-Pan Tex-Mex Organic Beef Tacos
# 3.13: One-Pot Black Bean & Poblano Soup
# 3.15: One-Pot Longhorn Turkey & Bean Chili
#
# Top 20 dissimilar:
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(data_pd.iloc[idx].sort_values(ascending=False))
# Out:
# cauliflower-florets                                 1
# salt                                                1
# yellow-onion                                        1
# t-easy-cleanup                                      1
# t-dinners                                           1
# t-spicy                                             1
# southwest-blend-spice                               1
# veggie-stock-concentrate                            1
# cooking-oil                                         1
# black-beans                                         1
# tomato-paste                                        1
# blue-corn-tortilla-chips                            1
# long-green-pepper                                   1
# tomato                                              1
# ground-turkey                                       1
# tex-mex-paste                                       1
# mexican-spice-blend                                 1
# ...
