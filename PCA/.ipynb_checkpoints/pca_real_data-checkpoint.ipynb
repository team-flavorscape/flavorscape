# %%
import pickle
import numpy as np

import pandas
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
num_components = 10

with open('/home/aleks/hackatum/flavorscape/data/recipes_10k.pkl', 'rb') as file:
    data_pd = pickle.load(file)

# %%
print(data_pd.sum(axis=0).sort_values(ascending=False))
# Out:
# salt                   8900
# pepper                 8745
# butter-milk            5391
# olive-oil              4645
# cooking-oil            3792
#                        ...
# t-destination-italy       0
# t-extra-spicy             0
# t-equipment-needed        0
# t-3-course-meal           0
# c-Southern Europe         0
# Length: 1121, dtype: int64

# %%
data_pd = (data_pd.reset_index()
                  .drop_duplicates(subset='index', keep='last')
                  .set_index('index').sort_index())
data_pd = data_pd.drop(data_pd.std()[data_pd.std() < 0.01].index.values, axis=1)

data_np = data_pd.to_numpy()
data_mean = data_np.mean(axis=0)
data_std = data_np.std(axis=0)

data_np.shape
# Out:
# (3570, 949)

# %%
data_np_norm = (data_np - data_mean) / data_std

pca = PCA(n_components=num_components)
dim_reduced_data = pca.fit_transform(data_np_norm)
print(pca.explained_variance_ratio_)
# Out:
# [0.00694538 0.00617521 0.00592973 0.00566672 0.00523087 0.0048372
#  0.00462626 0.00445852 0.00421059 0.00420296]

# %%
print(list(data_pd.columns))
# Out:
# ['sirloin-steak', 'kale', 'yukon-gold-potatoes', 'shallot', 'sour-cream', 'black-peppercorns', 'beef-stock-concentrate', 'salt', 'pepper', 'vegetable-oil', 'butter-milk', 'balsamic-vinegar', 'soy-sauce-soy', 'rosemary', 'yellow-onion', 'shredded-red-cabbage', 'mustard-seeds', 'white-wine-vinegar', 'cranberry-jam', 'olive-oil', 'sugar', 'chicken-breast', 'mozzarella', 'roma-tomato', 'panko-wheat-soy', 'paprika', 'dried-oregano', 'zucchini', 'italian-seasoning', 'orzo-wheat', 'fresh-mozzarella-milk', 'lemon', 'parsley', 'parmesan-cheese-milk', 'beef-sirloin-tips', 'scallions', 'garlic', 'cornstarch', 'ginger', 'yakisoba-noodles', 'ketchup', 'hoisin-sauce-jar', 'broccoli-florets', 'sesame-oil', 'sriracha-anchovy', 'basmati-rice', 'asparagus', 'sesame-seeds', 'parsnip', 'spinach', 'green-beans', 'almonds', 'beef-demi-glace', 'tricolor-peppercorns', 'truffle-zest', 'new-york-strip-steak', 'thai-chili-pepper', 'heirloom-tomatoes', 'shrimp', 'tagliatelle-pasta', 'grape-tomatoes', 'baby-carrots', 'herbes-de-provence', 'honey', 'button-mushrooms', 'carrots', 'jasmine-rice', 'ground-beef', 'arborio-rice', 'chicken-stock-concentrate', 'thyme', 'dried-chorizo', 'red-bell-pepper', 'cod-fillets-fish', 'garlic-powder', 'veggie-stock-concentrate', 'meyer-lemon', 'red-onion', 'mayonnaise-eggs', 'monterey-jack-cheese-milk', 'potato-buns', 'pesto-milk', 'spring-mix', 'sweet-potatoes', 'sweet-italian-chicken-sausage', 'diced-tomatoes', 'penne-pasta', 'tuscan-spice-blend', 
highlight = 'chicken-breast'

highlight_idx = data_pd.columns.get_loc(highlight)
plt.scatter(dim_reduced_data[:,0], dim_reduced_data[:,1], c=data_np[:,highlight_idx])

# %%
num_recipes = 20
idx = 0
print(f'{data_pd.index[idx]}')

diff = (dim_reduced_data - dim_reduced_data[idx])
dist = np.sqrt(np.sum(diff*diff, axis=1))
sorted_idx = dist.argsort()

print(f'\nTop {num_recipes} similar:')
for i in sorted_idx[:num_recipes]:
    print(f'{round(dist[i],2)}: {data_pd.index[i]}')
    
print(f'\nTop {num_recipes} dissimilar:')
for i in sorted_idx[-num_recipes:]:
    print(f'{round(dist[i],2)}: {data_pd.index[i]}')
# Out:
# When Steak Met Potatoes
#
# Top 20 similar:
# 0.0: When Steak Met Potatoes
# 0.0: Crushed Peppercorn Steak
# 1.05: 10-oz Ribeye and Mustard Peppercorn Sauce
# 1.36: Peppercorn-Crusted Sirloin with Shallot Pan Sauce
# 1.4: Sirloin Steak & Roasted Garlic Pan Sauce
# 1.41: Sirloin & Roasted Garlic Pan Sauce
# 1.46: Sirloin Steak Provençal
# 1.68: Beef Tenderloin and Balsamic Steak Sauce
# 1.69: Ribeye and Roasted Garlic Pan Sauce
# 1.79: Bisteccha con Fichi (Steak with Fig Sauce)
# 1.86: Meatloaf Au Poivre
# 1.95: Rib-Eye Steak Béarnaise
# 1.95: Sirloin and Sherry-Shallot Sauce
# 1.95: Sirloin and Sherry Shallot Sauce
# 1.99: Truffle Rib-Eye Steak
# 2.01: Beef Tenderloin & Balsamic Steak Sauce
# 2.14: Beef Tenderloin with Mushroom Sauce
# 2.15: New York Strip Steak in a Mushroom Sauce
# 2.19: Beef Tenderloin with Shallot Pan Sauce
# 2.19: Beef Tenderloin and Shallot Pan Sauce
#
# Top 20 dissimilar:
# 18.96: Sweet Thai Chili Turkey Lettuce Wraps
# 18.99: Shawarma-Spiced Chickpea & Bulgur Wraps
# 19.04: Bacon-Topped Cinnamon Roll Hotcake Bake
# 19.2: One-Pot Spicy Vegan Curry Stir-fry
# 19.2: One-Pot Spicy Vegan Curry Stir-Fry
# 19.2: One-Pot Spicy Coconut Curry Stir-Fry
# 19.37: One-Pot Spicy Chicken Curry Stir-Fry
# 19.43: One-Pot Spicy Shrimp Curry Stir-Fry
# 19.58: One-Pot Organic Beef Curry Stir-Fry
# 19.73: Maple Bacon Pull-Apart Bread
# 20.41: Spicy Coconut Curry Turkey Noodle Soup
# 20.53: Cinnamon Apple French Toast
# 20.65: Brown Sugar & Bacon Stuffed French Toast
# 20.8: Coconut Curry with Chickpeas
# 20.8: Coconut Curry with Chickpea & Bell Pepper
# 20.95: Spicy Coconut Curry Shrimp Noodle Soup
# 22.38: Apple-Pecan Mug Muffins
# 22.69: Lemon-Ricotta Dutch Baby
# 22.88: Spicy Coconut Curry Pork Noodle Soup
# 22.93: Spicy Coconut Curry Beef Noodle Soup
