# %%
import pickle
import numpy as np

import pandas
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
num_components = 10

# %%
with open('/home/aleks/hackatum/flavorscape/data/recipes_10k.pkl', 'rb') as file:
    data_pd = pickle.load(file)

data_pd = (data_pd.reset_index()
                  .drop_duplicates(subset='index', keep='last')
                  .set_index('index').sort_index())
data_pd = data_pd.drop(data_pd.std()[data_pd.std() < 0.1].index.values, axis=1)

data_np = data_pd.to_numpy()
data_mean = data_np.mean(axis=0)
data_std = data_np.std(axis=0)

data_np.shape
# Out:
# (3570, 209)

# %%
print(data_pd.sum(axis=0).sort_values(ascending=False))
# Out:
# salt                   2889
# pepper                 2831
# c-american             1763
# butter-milk            1629
# olive-oil              1451
#                        ...
# mayonnaise-eggs-soy      37
# pecans-nuts              37
# cucumber                 37
# harissa-powder           37
# prosciutto               37
# Length: 209, dtype: int64

# %%
data_np_norm = (data_np - data_mean) / data_std

pca = PCA(n_components=num_components)
dim_reduced_data = pca.fit_transform(data_np_norm)
print(pca.explained_variance_ratio_)
# Out:
# [0.03316411 0.02696041 0.02494467 0.01912254 0.01854279 0.01772406
#  0.01350147 0.01260525 0.01196663 0.01151059]

# %%
print(list(data_pd.columns))
# Out:
# ['sirloin-steak', 'kale', 'yukon-gold-potatoes', 'shallot', 'sour-cream', 'beef-stock-concentrate', 'salt', 'pepper', 'vegetable-oil', 'butter-milk', 'balsamic-vinegar', 'soy-sauce-soy', 'rosemary', 'yellow-onion', 'shredded-red-cabbage', 'white-wine-vinegar', 'olive-oil', 'sugar', 'chicken-breast', 'mozzarella', 'roma-tomato', 'panko-wheat-soy', 'dried-oregano', 'zucchini', 'italian-seasoning', 'fresh-mozzarella-milk', 'lemon', 'parsley', 'parmesan-cheese-milk', 'scallions', 'garlic', 'cornstarch', 'ginger', 'ketchup', 'broccoli-florets', 'sesame-oil', 'sriracha-anchovy', 'basmati-rice', 'asparagus', 'sesame-seeds', 'spinach', 'green-beans', 'almonds', 'beef-demi-glace', 'thai-chili-pepper', 'heirloom-tomatoes', 'shrimp', 'grape-tomatoes', 'honey', 'button-mushrooms', 'carrots', 'jasmine-rice', 'ground-beef', 'arborio-rice', 'chicken-stock-concentrate', 'thyme', 'garlic-powder', 'veggie-stock-concentrate', 'red-onion', 'mayonnaise-eggs', 'monterey-jack-cheese-milk', 'pesto-milk', 'spring-mix', 'sweet-potatoes', 'sweet-italian-chicken-sausage', 'diced-tomatoes', 'penne-pasta', 'tuscan-spice-blend', 'lime', 'dill', 'dijon-mustard-glass-jar', 'arugula', 'walnuts-tree-nuts', 'dried-cranberries', 'cilantro', 'avocado', 'black-beans', 'cumin', 'chili-flakes', 'maple-syrup', 'pork-tenderloin', 'buns-wheat-milk-eggs-soy', 'cheddar-cheese', 'fry-seasoning', 'israeli-couscous-wheat', 'garlic-herb-butter', 'brussels-sprouts', 'poblano-pepper', 'ground-pork', 'fajita-spice-blend', 'tomato-paste', 'chipotle-chili-powder', 'flour-tortillas-wheat-soy', 'chicken-breast-strips', 'cream-cheese-milk', 'southwest-blend-spice', 'dried-thyme', 'ciabatta-bread', 'feta-cheese-milk', 'apricot-jam', 'spaghetti-wheat', 'crushed-tomatoes', 'pineapple', 'cheese-tortelloni', 'ground-turkey', 'hot-sauce', 'mexican-cheese-blend', 'corn', 'chives', 'bbq-sauce-2oz', 'persian-cucumber', 'chicken-cutlets', 'radishes', 'peanuts', 'long-green-pepper', 'flour-wheat', 'milk', 'green-bell-pepper', 'pepper-jack-cheese', 'demi-baguette', 'baby-carrots-stemmed', 'chili-powder', 'eggs', 'peas', 'prosciutto', 'jalapeno', 'mixed-greens', 'beef-tenderloin-filets', 'cauliflower-florets', 'cavatappi-wheat', 'bacon', 'italian-cheese-blend', 'pork-chops', 'cream-sauce-base', 'guacamole', 'cucumber', 'mexican-spice-blend', 'bell-pepper', 'red-wine-vinegar', 'apple', 'pecans-nuts', 'basil', 'shredded-carrots', 'marinara-cup', 'crispy-fried-onions', 'curry-powder', 'coconut-milk', 'soy-sauce', 'sweet-thai-chili-sauce', 'yogurt', 'shawarma-spice-blend', 'mushroom-stock-concentrate', 'smoked-paprika', 'balsamic-glaze', 'bavette-steak', 'tex-mex-paste', 'smoky-red-pepper-crema', 'white-cheddar-cheese', 'cooking-oil', 'sweet-soy-glaze', 'rice-wine-vinegar', 'coleslaw-mix', 'ricotta-milk', 'creme-fraiche', 'tomato', 'flatbread', 'ponzu-sauce', 'mayonnaise-eggs-soy', 'bun-wheat-milk-eggs-soy', 'ramen-noodles', 'sweet-and-smoky-bbq-seasoning', 'blue-corn-tortilla-chips', 'gouda-cheese', 'potatoes', 'honey-dijon-dressing', 'sourdough-bread', 'chickpeas', 'harissa-powder', 'sliced-almonds', 'baby-lettuce', 'mini-cucumber', 't-gluten-free', 't-spicy', 't-veggie', 't-family-friendly', 't-one-pan', 't-quick', 't-vegan', 't-calorie-smart', 't-climate-score-good', 't-carb-smart', 't-easy-prep', 't-easy-cleanup', 't-climate-score-superstar', 't-climate-score-fair', 't-protein-smart', 't-mediterranean', 't-dinners', 't-new', 't-lunches', 't-seasonal', 'c-american', 'c-asian', 'c-fusion', 'c-italian', 'c-mexican', 'c-mediterranean', 'c-latin', 'c-middle-eastern']

# %%
highlight = 'c-mediterranean'

highlight_idx = data_pd.columns.get_loc(highlight)
plt.scatter(dim_reduced_data[:,0], dim_reduced_data[:,1], c=data_np[:,highlight_idx])

# %%
num_recipes = 20
idx = 0
print(f'{data_pd.index[idx]}')

diff = (dim_reduced_data - dim_reduced_data[idx])
dist = np.sqrt(np.sum(diff*diff, axis=1))
sorted_idx = dist.argsort()

print(f'\nTop {num_recipes} similar:')
for i in sorted_idx[:num_recipes]:
    print(f'{round(dist[i],2)}: {data_pd.index[i]}')
    
print(f'\nTop {num_recipes} dissimilar:')
for i in sorted_idx[-num_recipes:]:
    print(f'{round(dist[i],2)}: {data_pd.index[i]}')
# Out:
# "Little Ears" Pasta
#
# Top 20 similar:
# 0.0: "Little Ears" Pasta
# 1.52: Burrata and Lemon Zest Ravioli
# 1.59: Pillowy Parmesan Raviolini
# 1.74: Pancetta Flatbread Pizzas
# 1.77: Penne Arrabbiata
# 1.84: Pan-Seared Gnocchi
# 1.84: Toasty Pesto Gnocchi
# 1.84: Italian Sausage and Baby Broccoli Pasta
# 1.85: Mario Batali's Spaghetti
# 1.93: One-Pan Tortelloni Pesto Gratin
# 1.96: Winner Winner Chicken Orzo Dinner
# 2.0: Pasta Swirls and Sauce
# 2.01: Creamy Pesto Grilling Cheese Ciabattas
# 2.1: Rapid Butternut Squash Agnolotti
# 2.1: Eggy Sausage Flatbreads
# 2.11: Butternut Squash Agnolotti
# 2.19: Roasted Portobello Sandwiches
# 2.21: Pork Sausage Spaghetti alla Positano
# 2.25: Roasted Garlic Herb Penne
# 2.32: Lemon Pepper Chicken Linguine
#
# Top 20 dissimilar:
# 14.87: One-Pan Shawarma Turkey Lettuce Wraps
# 14.92: Vegan Thai Coconut Curry Tofu
# 14.97: Sweet Thai Chili Turkey Lettuce Wraps
# 15.19: Sweet Thai Chili Pork Lettuce Wraps
# 15.32: One-Pan Spiced Turkey Lettuce Wraps
# 15.97: Thai Chicken & Ginger Curry
# 16.03: Thai Ginger Chicken Curry
# 16.14: Shawarma-Spiced Chickpea Couscous Bowls
# 16.18: Thai Ginger Turkey Curry
# 16.26: Thai Ginger Shrimp Curry
# 16.47: Shawarma Chickpea Couscous Bowls
# 16.57: One-Pot Spicy Coconut Curry Stir-Fry
# 16.59: Vegan Coconut Curry Tofu Lettuce Wraps
# 16.6: One-Pot Spicy Chicken Curry Stir-Fry
# 16.69: One-Pot Spicy Shrimp Curry Stir-Fry
# 16.72: One-Pot Organic Beef Curry Stir-Fry
# 16.91: Vegan Thai Ginger Curry
# 17.27: Thai Ginger Curry
# 17.93: One-Pot Spicy Vegan Curry Stir-Fry
# 17.93: One-Pot Spicy Vegan Curry Stir-fry
